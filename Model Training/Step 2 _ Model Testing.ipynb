# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle 

from sklearn.ensemble import RandomForestClassifier

with open("/content/drive/My Drive/Selling Project/Real Time Projects/\
Twitter Sentimental Analysis/Data Files/vectorizer.pkl", "rb") as f: 
    vectoriser = pickle.load(f)

# %%
input_text = ""
input_vector = vectoriser.transform([input_text]).toarray()
input_vector
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
with open("/content/drive/My Drive/Selling Project/Real Time Projects/\
Twitter Sentimental Analysis/Data Files/Random_forest.pkl", "rb") as f: 
    model = pickle.load(f)

# %%
model.predict(input_vector)
# Out:
# array([0])

# %%
model.predict_proba(vectoriser.transform(['user used to get money']).toarray())
# Out:
# array([[1., 0.]])

# %%
import sklearn

sklearn.__version__
# Out:
# '1.0.2'

# %%
import pickle

pickle.format_version
# Out:
# '4.0'
